# %% [markdown]
# <a href="https://colab.research.google.com/github/aleylani/Python/blob/main/laboration/sweet_and_conquer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Laboration - Sweet & Conquer

# %% [markdown]
# **[Top Secret] Intelligence Briefing**
#
#
# Mayday! Mayday!
#
# One of the farmers of Fire Nation, whilst on a trip abroad to the neighbouring Earth Kingdom, was bored and apparently threw an apple at a local peasant.
#
# Now, 24h hours later, the world is at war.
#
# The conflict first involved only Fire Nation & the Earth Kingdom - but the Water Tribe and the Air Nomads swiftly decided to join in as well (for some random reason).
#
# Rumour is that they also wanted to join in on the apple free-for-all fiesta.
#
#
# **Main objective**
#
# Evidently, to win 'the apple wars', the goal of each faction is to steal all fruits from the others.
#
# Our objective is to simulate the dynamics of this little... dispute.
#
#
# **Grading criteria & general instructions**
#
# In general, grading will be based on the code in it's entirety. Extra weight will be put on readability, so think carefully about proper variable usage, method naming & supplemental comments. Importantly, also make sure to implement type hints wherever applicable!
#
# The tasks are categorized into difficulty tiers. To pass the lab (betyg G), you only need to work on the tasks designated with * (1 star) and completing most of them in a satisfactory manner.
#
# Succesfully making progress on and, in large, completing the tasks marked with additional stars provides a chance for the higher grade (betyg VG).

# %% [markdown]
# ## Tasks
#
# Here's the boilerplate (starter code) for a class called Faction that you'll be working on. The instances of this class will represent the different competing factions.

# %%
import random 
import time
import matplotlib.pyplot as plt

class Faction:
                    
    """This class takes int diffrent factions along with their names and the amount of individual fruit 
        they have and pereformes varius task depending on the method that is being called""" 

    def __init__(self, name:str, apples:int, bananas:int, oranges:int, strawberries:int):

        # Check if the 'name' argument is a string
        # If not, print an error message and raise a TypeError  
        if not isinstance(name,str):
            print('The name must be a string')
            raise TypeError
        

        # Check if the input is an integer
        # If not, print an error message and raise a TypeError 
        # Check if the input is within the acceptable range of 0-200
        # If not, print an error message and raise a ValueError      
        if not isinstance(apples,int):
            print('the amount of strawberries needs to be a int number')
            raise TypeError
        elif  apples < 0 or apples > 200:
            print('The amound of apples need to be between 0-200')
            raise ValueError
        
        if not isinstance(bananas,int):
            print('the amount of bananas needs to be a int number')
            raise TypeError
        elif bananas < 0 or bananas > 200:
            print('The amound of bananas need to be between 0-200')
            raise ValueError
        
        if not isinstance(oranges,int):
            print('the amount of oranges needs to be a int number')
            raise TypeError
        elif oranges < 0 or oranges > 200:
            print('The amound of oranges need to be between 0-200')
            raise ValueError
        
        if not isinstance(strawberries,int):
            print('the amount of strawberries needs to be a int number')
            raise TypeError
        elif strawberries < 0 or strawberries > 200:
            print('The amound of strawberries need to be between 0-200')
            raise ValueError
        
        self.__name = name
        self.__apples = apples
        self.__bananas = bananas
        self.__oranges = oranges
        self.__strawberries = strawberries


    def __repr__(self)->str:
        
        return f'Faction(name= {self.__name}, apples= {self.__apples}, oranges= {self.__oranges}, bananas= {self.__bananas}, strawberries= {self.__strawberries})\n'

    # All "methodes" with a @property above them are a way for the user to
    # call upon and access a specifik attributes without being able to alter it
    @property
    def name(self)->str:

        return self.__name
    
    @property
    def apples(self)->int:

        return self.__apples
    
    @property
    def bananas(self)->int:

        return self.__bananas

    @property
    def oranges(self)->int:

        return self.__oranges

    @property
    def strawberries(self)->int:
        
        return self.__strawberries

    def inventory(self)->int:           # Method to calculate the total inventory of fruits in the faction

        # Add all the values of the fruit together to get the total_fruit_inventory
        total_fruit_inventory = self.__apples + self.__strawberries + self.__bananas + self.__oranges
        
        return int(total_fruit_inventory)    # Returns the total_fruit_inventory as an int
    

    def status(self):                  # Method to print the status of the faction based on their total fruit inventory
        
        total_fruit_inventory = self.inventory() # Stores the total inventory of self.faction in the variable total_fruit_inventory

        # Prints out different messages depending on the how much fruit self.faction has
        if total_fruit_inventory <= 150:

            print(f'This aint nothin but a scratch! {self.__name} might be struggling for the moment, with only {total_fruit_inventory} left, but will be back with vengance!.')

        if 150 < total_fruit_inventory <= 500:

            print(f'The proud {self.__name} is VERY eager to toss some apples! We have {total_fruit_inventory} left, where are the opponents?!')
        
        if 500 < total_fruit_inventory:

            print(f'{self.__name} is GODLIKE! Their position is super dominant with a total of {total_fruit_inventory} left!')
    

    def alter_stock_value(self,fruit:str,stock:int):
        
        # Check if the 'stock' argument is an integer
        # If not, print an error message and raise a TypeError
        if not isinstance(stock,int):
            print(f'The stock argument needs to be an int, your input is a {type(stock)}')
            raise TypeError
        
        # Check if the 'stock' is within the acceptable range of 0-200
        # If not, print an error message and raise a ValueError
        elif stock < 0 or stock > 200:
            print('The stock argument needs to be between 0-200')
            raise ValueError
         

        # Check if the 'fruit' argument is a string
        # If not, print an error message and raise a TypeError  
        if not isinstance(fruit, str):
            print(f'Your fruit argument needs to be a string, your input is a {type(fruit)}')
            raise TypeError

        elif fruit.lower() == 'apples':         #
            self.__apples = stock

        elif fruit.lower() == 'oranges':        #
            self.__oranges = stock                  ## chechs if the input (stock) mathces any of the fruit in stock

        elif fruit.lower() == 'bananas':        #
            self.__bananas = stock

        elif fruit.lower() == 'strawberries':   #
            self.__strawberries = stock

        else:                                   # If the fruit type is not recognized, print an error message and raise a ValueError              
            print(f'{fruit} is not a fruit in the Faction class')   
            raise ValueError

    
    def visualize_resources(self):      # Method to visualize the faction's resources using a bar chart
        
        # Creating a dictionary with fruit names as keys and their counts as values
        all_fruits_dict = {'apples': self.__apples, 'bananas': self.__bananas, 'oranges': self.__oranges, 'strawberries': self.__strawberries}

        # Iterating over the dictionary to get the name and count of each fruit
        for fruit_name, fruit_count in all_fruits_dict.items():
            
            # Checking the count of each fruit and assigning a color based on the count
            
            if fruit_count >= 100:
                bar_color = 'green'
             
            if 50 < fruit_count <= 100:
                bar_color = 'orange'
                
            if fruit_count <= 50:
                bar_color = 'red'

            plt.bar(fruit_name, fruit_count, color=bar_color)

        
        plt.xlabel('Fruits')            # This will write "Fruits" under the x-lable
        plt.ylabel('amount in stock')   # This will write "amount in stock" under the y-lable
        plt.title(f'fruits in stock for {self.__name}')    # This will make the title, of the barplot, to "fruits in stock"
        plt.yticks([x for x in range(0,201,25)])

        plt.show()                      # Displaying the bar chart
        

    def organical_growth(self):         # Method to simulate the organic growth of fruits in the faction

        # Creating a dictionary to hold each type of fruit and its corresponding count.
        all_fruits_dict = {'apples': self.__apples, 'bananas': self.__bananas, 'oranges': self.__oranges, 'strawberries': self.__strawberries}
        
        for fruit_name, fruits in all_fruits_dict.items():  # Iterating over each fruit type and count in the dictionary.
            max_cap = ' '

            growth = random.randint(1,5)                    # Randomly generating the number of fruits to be added (growth) between 1 and 5.
            if fruits + growth < 200:                       # Checking if the total number of fruits after adding the growth is less than 200 if so, new_total = fruits + growth .
                new_total = fruits + growth
                if fruit_name == 'apples':                  #
                    self.__apples = new_total                 #
                elif fruit_name == 'bananas':               #   #
                    self.__bananas = new_total                # # # Assigning the new total count to the appropriate fruit type attribute.
                elif fruit_name == 'oranges':               #   #
                    self.__oranges = new_total                #
                elif fruit_name == 'strawberries':          #
                    self.__strawberries = new_total

            else:                                           # If the total fruits count exceeds 200, reducing the growth to fit the maximum capacity.
                while fruits + growth > 200: 
                    growth-=1   
                new_total = 200                             # Setting the new total count to the maximum capacity of 200.
                max_cap = ' the maximum capacity of: '      # Assigning the maximum capacity to the appropriate fruit type attribute.
                if fruit_name == 'apples':                  #
                    self.__apples = new_total                 #
                elif fruit_name == 'bananas':               #   #
                    self.__bananas = new_total                # # # Assigning the new total count to the appropriate fruit type attribute.
                elif fruit_name == 'oranges':               #   #
                    self.__oranges = new_total                #
                elif fruit_name == 'strawberries':          #
                    self.__strawberries = new_total

                                                           # Printing the result of the harvesting, including the growth, the fruit type, and the new total count.            
            print(f'Glorious {self.__name} has harvested {growth} more {fruit_name}, giving them a total of{max_cap}{new_total} {fruit_name}!')        

    
    # Overloading the multiplication operator for the Faction class
    # This method allows a Faction object to attack another Faction object
    def __mul__(self, other):

        others_inventory = other.inventory()    # Getting the total fruit inventory of the other faction
        
        if others_inventory >0:                 # Checking if the "other"/defending faction has any fruit left for an attack to be valid
            
            humiliation = False

            print(f'going in to this war {self.__name}s inventory looks like this\n')
            print(self)
            self.visualize_resources()
            print(f'and {other.__name}s inventory looks like this')
            print(other)
            other.visualize_resources()

            attack_efficiancy = ''              # A variable to hold the print of the diffrent type of attacks.
            
            time.sleep(3)
            print(f'The attack by {self.__name} on {other.__name}, start in\n3')
            time.sleep(1)                       #
            print('2')                           #
            time.sleep(1)                         ## Printing a countdown to the attack
            print('1')                           #
            time.sleep(1)                       #
           
            if random.uniform(0, 1) < 0.7:      # This line randomizes a float between 0-1 and if the float is less than 0,7 (70% of the time) then the code bellow gets executed
                extra_fruits_taken = []
                print(f'{self.__name} won over {other.__name},')
                
                #burned_fruit  = [extra for extra in extra_fruits_taken]
                for fruit in ['__apples', '__bananas', '__oranges', '__strawberries']:  # Iterating through each type of fruit in the factions
                     # If the other faction has more than 5 of the current type of fruit, they can be stolen
                     

                    if other.inventory() <=10:

                        # There is a 90% chance for a normal attack, and 10% for a critical attack
                        if random.uniform(0, 1) < 0.9:

                            fruit_taken = int(getattr(other, f"_Faction{fruit}") * 0.2)
                            attack_efficiancy ='The attack was a Normal attack'
                           
                        
                        else:
                        
                            fruit_taken = int(getattr(other, f"_Faction{fruit}") * 0.4)
                            attack_efficiancy ='The attack was a Critical attack'
                           
                    
                    # If the other faction has less than 5 of the current fruit, all of them can be stolen
                    elif other.inventory() <=10:
                        fruit_taken = other.inventory()
                        humiliation = True
                        
                        extra_fruits_taken.append(fruit_taken)
                    
                    # Sets the new value of "others" fruit count
                    setattr(other, f"_Faction{fruit}", getattr(other, f"_Faction{fruit}") * 0)

        

                    # Ensuring that the attacking faction does not exceed the maximum limit of 200 for each type of fruit
                    while getattr(self, f"_Faction{fruit}") + fruit_taken >200:
                            fruit_taken -=1

                    # Increasing the fruit count of the attacking faction by the number of fruits stolen
                setattr(self, f"_Faction{fruit}", getattr(self, f"_Faction{fruit}") + fruit_taken)
                if humiliation:
                    print('Humiliation')

                if getattr(self, f"_Faction{fruit}") == 200:   

                    print(f'{self.__name} has to many {fruit} to carry home and so thay burned {sum(extra_fruits_taken)-1} {fruit} right infront of {other.__name}')    
            
                   

                # Printing the type of attack and the outcome
                print(attack_efficiancy)    
                time.sleep(1)
                
                        
                #if to_print:
                   # print(f'this manny frout where burned {sum(extra_fruits_taken)}')
               
                print(f'As a result of the attack by {self.__name} on {other.__name}, {self.__name} as taken 20%\n'
                      f'of the the stock of all fruits that {other.__name} had')
                #self.visualize_resources()
                #other.visualize_resources()

            else:   # In case the attack was not successful
                print(f'{other.__name} defended succssesfully!')

        else:       # In case the other faction has no fruits left
            print(f'{other.name} has no fruit left.\nThere is no GLORY in kicking down on an opponent already brought to its knees.')

# %% [markdown]
# **1)***
#
# * The __init__() method
#
# This method should be able to accept the following user-provided arguments: **name**, **apples**, **oranges**, **bananas**, **strawberries** and initiate corresponding attributes with the same name as the arguments.
#
# Attribute description:
#
# **name**         : the name of the faction
#
# **apples**       : amount of apples currently controlled
#
# **oranges**      : amount of oranges currently controlled
#
# **bananas**      : amount of bananas currently controlled
#
# **strawberries** : amount of strawberries currently controlled
#
# Restrictions:
#
# All attributes should be **private** with two underscores.
#
# The name should be handed in as a string. Implement relevant checks and raise TypeError (with a suitable message) else.
#
# The fruit amounts should be given in integers. Implement relevant checks and raise TypeError (with a suitable message) else.
#
# Furthermore, the fruit amounts should only be between 0-200. Implement relevant checks and raise ValueError (with a suitable message) else.

# %%
# you should now be able to create the following instances

fire_nation = Faction('Fire Nation', 193, 193, 193, 50)
earth_kingdom = Faction('Earth Kingdom', 100, 150, 200, 10)
water_tribe = Faction('Water Tribe', 10, 10, 3, 3)
air_nomads = Faction('Air Nomads', 100, 100, 100, 100)

# %%
fire_nation * water_tribe

print()
print(fire_nation)
print(water_tribe)
# Out:
# going in to this war Fire Nations inventory looks like this
#
# Faction(name= Fire Nation, apples= 193, oranges= 193, bananas= 193, strawberries= 50)
# and Water Tribes inventory looks like this
# Faction(name= Water Tribe, apples= 10, oranges= 3, bananas= 10, strawberries= 3)
# The attack by Fire Nation on Water Tribe, start in
# 3
# 2
# 1
# Fire Nation won over Water Tribe,
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# c:\Users\M\Desktop\skol projekt\maurice_issa_sweet_conquer.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/M/Desktop/skol%20projekt/maurice_issa_sweet_conquer.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> fire_nation * water_tribe
#       <a href='vscode-notebook-cell:/c%3A/Users/M/Desktop/skol%20projekt/maurice_issa_sweet_conquer.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> print()
# ...

# %%
# neither one of these should not work (try each one order)
 
#pancake_cult = Faction('Pancake Cult', 30, 20, 24, 160)
#cupcake_assassins = Faction('Cupcake Assassins', 1, 1, 1, )
#milk_drinkers = Faction(['Milk Drinkers'], 30, 20, 150, 160)

# %% [markdown]
# **2)***
#
# * The __repr__() method
#
# This method takes no user-provided arguments. When called on, **returns** a clear and concise string with information about the current attributes of this instance.
#
# For example, using the following code:
#
#         print(fire_nation)
#
# should print out the following string:
#
#         Faction(name='Fire Nation', apples=100, oranges=100, bananas=100, strawberries=100)

# %%
# you should now be able to run this

print(fire_nation)
print(earth_kingdom)
print(water_tribe)
print(air_nomads)

# %% [markdown]
# **3)***
#
# * properties
#
# These special methods takes no user arguments. They should allow the user to read the current values of the various private attributes.
#
# For example, using the following code:
#
#         faction_name = fire_nation.name
#         print(faction_name)
#
# should print out the following string:
#
#         Fire Nation

# %%
# this code should now reproduce the output in the example

faction_name = fire_nation.name
print(faction_name)

fraction_banana_holdings = fire_nation.bananas
print(fraction_banana_holdings)

# %% [markdown]
# **4)***
#
# * The inventory() method
#
# This method takes no user provided arguments. It **returns** the total amount of fruits the faction currently possess - and this should be a single integer.

# %%
# try it yourself after implementing
air_nomads.inventory()

# %% [markdown]
# **5)***
#
# * The status() method
#
# This method takes no user provided arguments. It prints out the state of each faction depending on the total number of fruits they currently possess.
#
# Here's a guide to what should be printed out, depending on the total number of fruits
#
#         total <= 150:
#
#                 This aint nothin but a scratch! {faction_name} might be struggling for the moment, but will be back with vengance!
#
#         150 < total <= 500:
#
#                 The proud {faction_name} is VERY eager to toss some apples! Where are the opponents?!
#
#         500 < total:
#
#                 {faction_name} is GODLIKE! Their position is super dominant!

# %%
fire_nation.status()

# %% [markdown]
# **6)***
#
# * The alter_stock_value() method
#
# This method should allow the user, if that person really insists, to use this method to change the internal stock values of the different fruits.
#
# It should take two user provided arguments, called **fruit** and **stock**.
#
# The **fruit** argument is supposed to be a string, and only accept one of the following values 'apples', 'oranges', 'bananas', 'strawberries'.
#
# The **stock** argument is supposed to be an integer and only accept values in the range 0-200.
#
# Implement relevant checks and raise suitable errors alongside helpful error messages for both.
#
# The method should, if the user provides valid arguments, change the stock value of the given fruit to what the user has indicated.

# %%
print(fire_nation.oranges)
fire_nation.alter_stock_value('oranges',10)
print(fire_nation.oranges)

# %% [markdown]
# **7)****
#
# * The visualize_resources() method
#
# This method takes no user provided arguments. It should plot a **bar chart** which visualises the quantity of each fruit currently possessed by the faction.
#
# For bonuspoints, make sure that the color each individual bar is
#
#     green if fruit_amount >= 100
#     orange if 50 < fruit_amount <= 100
#     red if fruit_amount <= 50
#
# In general, try to make the plot 'visually appealing'. You might have to do some research online on how to do this.

# %%
# try it yourself after implementing

fire_nation.visualize_resources()

water_tribe.visualize_resources()

# %% [markdown]
# **8)****
#
# * The organical_growth() method
#
# This method takes no user provided arguments. It represents the fact that each faction has natural farms that grow fruits.
#
# When this method is called by a faction, it should randomly increase the amound of each, individually, by a seperate random amount ranging from 1 to 5.
#
# Remember that the maximum amount of each fruit, individually, is 200. Make sure that the amount is unable to increase beyond that.
#
# Also, print out the changes that are happening. For example:
#
#     if current_amount_of_oranges < 200:
#
#         Glorious {faction_name} has harvested 4 oranges, to a new total of 164!
#
#     if current_amount_of_oranges == 200:
#
#         Glorious {faction_name} is already at maximum capacity for oranges!

# %%
fire_nation.organical_growth()

# %% [markdown]
# **9)*****
#
# * The __mul__() method
#
# Here we go! We're going to overload the * operator to represent an attack on a rival faction!
#
#     When an attack occurs, there will be an 70% probability of it being successful.
#
# If the attack fails, the defender is considered to have defended skillfully and nothing else happens.
#
#     A successful attack will transfer, to the attacking faction, 20% of all remaining fruits (of all sorts) from the defending rival faction.
#
# In addition, if an attack is successful, there is an independent 10% probability of it being CRITICAL. This will increase the percentage looted to 40%, instead of 20%
#
#     Importantly, if the defending faction has no resources left once the attack starts, the aggressor should be prompted to choose another target since there is no GLORY in kicking down on an opponent already brought to its knees.
#
# Remember that the total number of each fruit a faction can hold can't increase beyond 200. If more is looted by the attacker  can be held by the attack, we consider those abundant fruits 'casaulties of war'. Meaning, the defending faction still loses them, but they are simply lost in the chaos and not added to the attackers stockpile.
#
#     Additionally, if for example a faction only has a few remaining (say ~5) fruits remaining of any given kind - implement some functionality for a 'humilitating blow' whereby the attacker steals all remaining fruits. This is needed since only looting percentages will make it impossible to nullify a factions resources.
#
# For each of the possible actions described above, print out some cool texts so that the user is able to clearly follow the silliness!
#
#     As a bonus, you can first import time, and then add time.sleep(2) after each print, to create some suspense.

# %%
print()
print(fire_nation)
print(water_tribe)
fire_nation * water_tribe

print()
print(fire_nation)
print(water_tribe)
